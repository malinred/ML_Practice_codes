# %%
# !pip install mne
import matplotlib.pyplot as plt
import os
import mne

# %%
raw = mne.io.read_raw_fif("sample_audvis_raw.fif")
print("_______________________________")
print(raw.info)
print("_______________________________")
raw_meg = raw.pick(['meg'])
# Out:
# Opening raw data file sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# _______________________________
# <Info | 21 non-empty values
#  acq_pars: ACQch001 110113 ACQch002 110112 ACQch003 110111 ACQch004 110122 ...
#  bads: 2 items (MEG 2443, EEG 053)
#  ch_names: MEG 0113, MEG 0112, MEG 0111, MEG 0122, MEG 0123, MEG 0121, MEG ...
#  chs: 204 Gradiometers, 102 Magnetometers, 9 Stimulus, 60 EEG, 1 EOG
#  custom_ref_applied: False
#  description: acquisition (megacq) VectorView system at NMR-MGH
#  dev_head_t: MEG device -> head transform
#  dig: 146 items (3 Cardinal, 4 HPI, 61 EEG, 78 Extra)
#  events: 1 item (list)
#  experimenter: MEG
#  file_id: 4 items (dict)
#  highpass: 0.1 Hz
#  hpi_meas: 1 item (list)
#  hpi_results: 1 item (list)
#  lowpass: 172.2 Hz
#  meas_date: 2002-12-03 19:01:10 UTC
#  meas_id: 4 items (dict)
#  nchan: 376
#  proj_id: 1 item (ndarray)
#  proj_name: test
#  projs: PCA-v1: off, PCA-v2: off, PCA-v3: off
#  sfreq: 600.6 Hz
# >
# _______________________________

# %%
raw_meg = raw_meg.drop_channels(raw_meg.info["bads"])
print("All the MEG signals in the dataset plotted within 1 graph")
plots = raw_meg.plot()
# Out:
# All the MEG signals in the dataset plotted within 1 graph
# <MNEBrowseFigure size 1920x1043 with 5 Axes>

# %%
three_d = mne.viz.plot_sensors(raw_meg.info, kind='3d', show_names=True, sphere=0.08)
